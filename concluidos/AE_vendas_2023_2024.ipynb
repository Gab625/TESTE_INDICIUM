# %%
import pandas as pd

df = pd.read_csv("datasets/vendas_2023_2024.csv")
df

# %%
df_final = df['sale_date'].astype('datetime64[us]')
df_final

df_final.to_csv('vendas_2023_2024.csv', index=False, sep=",", encoding='utf-8-sig')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9895 entries, 0 to 9894
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          9895 non-null   int64
#  1   id_client   9895 non-null   int64
#  2   id_product  9895 non-null   int64
#  3   qtd         9895 non-null   int64
#  4   total       9895 non-null   float64
#  5   sale_date   9895 non-null   str
# dtypes: float64(1), int64(4), str(1)
# memory usage: 464.0 KB

# %%
df.head()
df.tail()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9895 entries, 0 to 9894
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          9895 non-null   int64
#  1   id_client   9895 non-null   int64
#  2   id_product  9895 non-null   int64
#  3   qtd         9895 non-null   int64
#  4   total       9895 non-null   float64
#  5   sale_date   9895 non-null   str
# dtypes: float64(1), int64(4), str(1)
# memory usage: 464.0 KB

# %%
display(df)
# Out:
#         id  id_client  id_product  qtd      total   sale_date
# 0        0         42         105   11    3405.00  2023-09-10
# 1        1          3         136    9   16873.90  15-09-2024
# 2        2         25         139    7    9475.30  2024-08-13
# 3        4         20          23    5   55893.00  2023-02-03
# 4        5          8          57    4  451403.90  2024-02-12
# ...    ...        ...         ...  ...        ...         ...
# 9890  9995         30         139    6    8549.00  11-03-2023
# 9891  9996          9         111    7   28497.15  17-09-2023
# 9892  9997         38         123    2    5276.30  20-06-2023
# 9893  9998         33          97    6  771409.50  23-10-2024
# 9894  9999          8          20    6  185001.00  15-06-2023
#
# [9895 rows x 6 columns]

# %%
# NAO FAZ PARTE DO TESTE

# verificar_virgula = df['total'].astype(str).str.contains(',')
# verificar_virgula.sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id            0
# id_client     0
# id_product    0
# qtd           0
# total         0
# sale_date     0
# dtype: int64

# %%
df['id_product'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       105
# 1       136
# 2       139
# 3        23
# 4        57
#        ...
# 9890    139
# 9891    111
# 9892    123
# 9893     97
# 9894     20
# Name: id_product, Length: 9895, dtype: int64>

# %%
df.describe()
# Out:
#                 id    id_client   id_product          qtd         total
# count  9895.000000  9895.000000  9895.000000  9895.000000  9.895000e+03
# mean   5000.755533    24.874583    75.255786     8.015260  2.637978e+05
# std    2887.000000    14.177715    43.533397     4.301723  3.900072e+05
# min       0.000000     1.000000     1.000000     1.000000  2.945000e+02
# 25%    2501.500000    13.000000    37.000000     4.000000  2.313820e+04
# 50%    4999.000000    25.000000    74.000000     8.000000  8.222500e+04
# 75%    7505.500000    37.000000   114.000000    12.000000  3.390945e+05
# max    9999.000000    49.000000   150.000000    15.000000  2.222973e+06

# %%
df.plot(kind='box',figsize=(14,4),subplots=True)
# Out:
# id               Axes(0.125,0.11;0.133621x0.77)
# id_client     Axes(0.285345,0.11;0.133621x0.77)
# id_product     Axes(0.44569,0.11;0.133621x0.77)
# qtd           Axes(0.606034,0.11;0.133621x0.77)
# total         Axes(0.766379,0.11;0.133621x0.77)
# dtype: object

# %%
outliers_excel = df[df['total'] > 900000]
outliers_excel.plot(kind='box',figsize=(14,4),subplots=True)
# Out:
# id               Axes(0.125,0.11;0.133621x0.77)
# id_client     Axes(0.285345,0.11;0.133621x0.77)
# id_product     Axes(0.44569,0.11;0.133621x0.77)
# qtd           Axes(0.606034,0.11;0.133621x0.77)
# total         Axes(0.766379,0.11;0.133621x0.77)
# dtype: object

# %%
dados_tipicos = df[df['total'] < 1000000]
dados_tipicos.to_csv('Dados_tipicos.csv', index=False)
dados_tipicos.plot(kind='box',figsize=(14,4),subplots=True)
# Out:
# id               Axes(0.125,0.11;0.133621x0.77)
# id_client     Axes(0.285345,0.11;0.133621x0.77)
# id_product     Axes(0.44569,0.11;0.133621x0.77)
# qtd           Axes(0.606034,0.11;0.133621x0.77)
# total         Axes(0.766379,0.11;0.133621x0.77)
# dtype: object

# %%
df_final = df['sale__date']
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Gabriel Prado\Documents\TESTE_INDICIUM\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale__date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
df['id_product'].value_counts()
# Out:
# id_product
# 116    88
# 56     85
# 74     85
# 127    83
# 33     83
#        ..
# 24     47
# 68     47
# 95     47
# 75     45
# 83     44
# Name: count, Length: 150, dtype: int64

# %%
menor_data = df['sale_date'].min()
menor_data
# Out:
# '01-01-2023'

# %%
maior_data = df['sale_date'].max()
maior_data
# Out:
# '31-12-2024'

# %%
menor_valor = df['total'].min()
menor_valor
# Out:
# np.float64(294.5)

# %%
maior_valor = df['total'].max()
maior_valor
# Out:
# np.float64(2222973.0)

# %%
media_valor = df['total'].mean()
media_valor
# Out:
# np.float64(263797.82826680137)
